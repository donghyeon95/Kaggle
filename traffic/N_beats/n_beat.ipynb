# %% [markdown]
# # N-Beat

# %% [markdown]
# !! 질문 사항 !!
# - N-beat stack 구현이 Trend, Trend, Trend...., seasonality, seasonality,seasonality....., noise, noise, ... 순이던데
# - Trend, seasonality, noise, Trend, seasonality, noise, .... 순서이면 안되나요?
#
# - 예상 이유 -> seasonality, noise를 계산 하면서 Trend를 잃어버리기 때문에??
# -

# %% [markdown]
# ### 관련 정리
# https://joungheekim.github.io/2020/09/09/paper-review/

# %% [markdown]
# - paper
# https://arxiv.org/abs/1905.10437

# %% [markdown]
# https://pytorch-forecasting.readthedocs.io/en/latest/tutorials/ar.html

# %% [markdown]
# https://github.com/philipperemy/n-beats

# %%
from datetime import datetime
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
import torch.nn.functional as F
import wandb

wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: donghyeon95 (use `wandb login --relogin` to force relogin)
# True

# %%
train_df = pd.read_csv("/USER/traffic/data/train.csv")
valid_df = pd.read_csv("/USER/traffic/data/validate.csv")
test_df = pd.read_csv("/USER/traffic/data/test.csv")

# %%
# train_df['datetime'] = pd.to_datetime(train_df['날짜'].astype('str')) + train_df['시간'].astype('timedelta64[h]')`

# %%
train_df['10'].values
# Out:
# array([ 83247,  89309,  66611, ..., 306008, 237447, 150312])

# %%
loads = ["10", "100", "101", "120", "121", "140", "150", "160", "200", "201", "251", "270", "300", "301", "351", "352", "370", "400", "450", "500", "550", "600", "650", "652", "1000",
"1020", "1040", "1100", "1200", "1510", "2510", "3000", "4510", "5510", "6000"]

# %% [markdown]
# ### Data Loader

# %%
class TimeseriesDataset(torch.utils.data.Dataset):   
    def __init__(self, data, backcast_length, forecast_length, scaler=None):
        self.data = data.values
        self.backcast_length = backcast_length #어떤 주기로 예측을 수행할 지 
        self.forecast_length = forecast_length #얼마나 에측할 것인지?        

    def __len__(self): 
        # 전체 중에서 윈도우를 밀고 가면서 생성한다고 보면 된다. 빼주는 이유는 마지막 윈도우의 길이를 확보해주기 위함이다. 
        return len(self.data) - self.backcast_length - self.forecast_length + 1

    def __getitem__(self, idx):
        x_end = idx + self.backcast_length
        y_end = x_end + self.forecast_length

        x = self.data[idx:x_end]
        y = self.data[x_end:y_end]
        
        x = torch.from_numpy(x).float()
        y = torch.from_numpy(y).float()
        
        return x, y

# %%
batch_size = 4
num_workers = 2
pin_memory = True

backcast_length = 24 * 7 # 1주일 data를 보고 예측할 것이다. 
forecast_length = 24 * 7 # 1주일치를 예측할 것이다. 
theta_dim=(2, 8, 3)
n_trend=3
n_seasonality=3
n_residual=3
hidden_dim=256 #논문에서는 256인데 학습을 빠르게 하기위해 64로 설정한 듯. 
learning_rate = 1e-4
num_epoch = 100

criterion = nn.MSELoss()

# %%
config = {
    'batch_size': batch_size,
    'backcast_length' : backcast_length,
    'forecast_length' : forecast_length,
    'theta_dim': theta_dim,
    'n_trend' : n_trend,
    "n_seasonality": n_seasonality,
    "n_residual": n_residual,
    "hidden_dim" : hidden_dim,
    "learning_rate" : learning_rate,
    "num_epoch": num_epoch,
    "criterion" : criterion,
}

wandb.init(config=config, project="TRAFFIC", entity="team6", name="N-beat-02")
# Out:
# Finishing last run (ID:20qarejw) before initializing another...
# <br/>Waiting for W&B process to finish, PID 22459... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss_mean</td><td>█▄▄▃▃▃▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_mean</td><td>▂▂▂▁▁▂▂▂▃▄▃▆▅▅▄▅█▅█▇▇▇▇▅▇▄▆▅▆▇▄▆▅▆▆▆▆▆▄▆</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss_mean</td><td>2154778762.6087</td></tr><tr><td>val_loss_mean</td><td>5695191040.0</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">N-beat-01</strong>: <a href="https://wandb.ai/team6/TRAFFIC/runs/20qarejw" target="_blank">https://wandb.ai/team6/TRAFFIC/runs/20qarejw</a><br/>
# Find logs at: <code>./wandb/run-20220221_061556-20qarejw/logs</code><br/>
# Successfully finished last run (ID:20qarejw). Initializing new run:<br/>
#                     Syncing run <strong><a href="https://wandb.ai/team6/TRAFFIC/runs/1ieasfal" target="_blank">N-beat-02</a></strong> to <a href="https://wandb.ai/team6/TRAFFIC" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/team6/TRAFFIC/runs/1ieasfal?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
train_loaders = []
val_loaders = []
test_loaders = []

for load in loads: 
    train_dataset = TimeseriesDataset(train_df[load], backcast_length, forecast_length) #현재 데이터의 평균과 분산으로 정규화
    val_dataset = TimeseriesDataset(valid_df[load], backcast_length, forecast_length) #치팅을 하면 안되기에 train의 평균과 분산으로 
    test_dataset = TimeseriesDataset(test_df[load], backcast_length, forecast_length) #치팅을 하면 안되기에 train의 평균과 분산으로

    train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, # train data의 순서를 외우지 못하게 하기위해 shffle을 해준다. 
                                                   num_workers=num_workers, pin_memory=pin_memory)
    train_loaders.append(train_dataloader)
    val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False, 
                                                   num_workers=num_workers, pin_memory=pin_memory)
    val_loaders.append(val_dataloader)
    test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, 
                                                   num_workers=num_workers, pin_memory=pin_memory)
    test_loaders.append(test_loaders)

# %% [markdown]
# ### N-beat Model

# %%
class NBeatsNet(nn.Module):
    def __init__(self,
                 forecast_length=168, #미래 24개의 데이터를 보겠다. 
                 backcast_length=168, #과거 96개의 데이터를 보겠다.
                 theta_dim=(2, 8, 3), # 2차식으로 trend를 보겠다. 
                 n_trend=3,
                 n_seasonality=3,
                 n_residual=3,
                 hidden_dim=256,
                 feature_dim=1):
        super(NBeatsNet, self).__init__()        
            
        self.trend_stack = []
        self.seasonality_stack = []
        self.residual_stack = [] #bs =[] 이건했는데 fs=[] 이거 안해줌
        # We can simply call pairplot on our DataFrame for an automatic visual analysis 

        for i in range(n_trend):
            self.trend_stack.append(Block(backcast_length, forecast_length, hidden_dim, theta_dim[0], mode='trend', feature_dim=feature_dim))    

        for i in range(n_seasonality):
            self.seasonality_stack.append(Block(backcast_length, forecast_length, hidden_dim, theta_dim[1], mode='seasonality', feature_dim=feature_dim))
        
        for i in range(n_residual):
            self.residual_stack.append(Block(backcast_length, forecast_length, hidden_dim, theta_dim[2], mode='residual', feature_dim=feature_dim))
        # We can simply call pairplot on our DataFrame for an automatic visual analysis 

        
        self.trend_stack = nn.ModuleList(self.trend_stack)
        self.seasonality_stack = nn.ModuleList(self.seasonality_stack)
        self.residual_stack = nn.ModuleList(self.residual_stack)

    def forward(self, backcast):# We can simply call pairplot on our DataFrame for an automatic visual analysis 
# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        backcast_stack = []
        forecast_stack = []

        for layer in self.trend_stack:
            b, f = layer(backcast)
            backcast_stack.append(b)
            forecast_stack.append(f)
            backcast = backcast - b

        for layer in self.seasonality_stack:
            b, f = layer(backcast)
            backcast_stack.append(b)
            forecast_stack.append(f)
            backcast = backcast - b


        for layer in self.residual_stack:
            b, f = layer(backcast)
            backcast_stack.append(b)
            forecast_stack.append(f)
            backcast = backcast - b

        backcast = torch.stack(backcast_stack, 0)
        forecast = torch.stack(forecast_stack, 0)
        return backcast, forecast


# ours
class Block(nn.Module):
    def __init__(self, backcast_length, forecast_length, hidden_dim, theta_dim, mode, feature_dim):
        # mode: season, trend, residual 
        # MLP : FC stack
        # 
        super(Block, self).__init__()
        self.backcast_length = backcast_length
        self.forecast_length = forecast_length
        self.theta_dim = theta_dim
        self.mode = mode

        self.MLP = nn.Sequential(
                nn.Linear(backcast_length * feature_dim, hidden_dim), 
                nn.ReLU(),
                nn.Linear(hidden_dim, hidden_dim),
                nn.ReLU(),
                nn.Linear(hidden_dim, hidden_dim),
                nn.ReLU(),
                nn.Linear(hidden_dim, hidden_dim),
                nn.ReLU()
            ) # univariate??multivariate??

        if mode == 'residual':
            # residual  
            self.theta_b = nn.Linear(hidden_dim, theta_dim * feature_dim)             
            self.theta_f = nn.Linear(hidden_dim, theta_dim * feature_dim)
            self.linear_b = nn.Linear(theta_dim, backcast_length)
            self.linear_f = nn.Linear(theta_dim, forecast_length)
            #레지듀얼은 과거와 미래의 경향성이 너무 없기 때문에 따로 계산을 한다. 

        else:
            # trend, seasonality# We can simply call pairplot on our DataFrame for an automatic visual analysis 
            self.theta = nn.Linear(hidden_dim, theta_dim*feature_dim)
            #수업과는 달리 backcast랑 forecast를 같은 것을 쓰기 위해.


    def forward(self, x):
        shape = x.shape
        # x: (batch size, backcast length, feature_dim)
        #24로 나눈 것은 24 step을 가면 1주기가 되도록....콜코
        t_b = ((torch.arange(start=0, end=self.backcast_length, device=x.device, dtype=torch.float) - self.backcast_length) / 24 ) # (backcast_len,)
        t_f = ((torch.arange(start=0, end=self.forecast_length, device=x.device, dtype=torch.float)) / 24 ) # (forecast_len,)

        # x -> h
        x = self.MLP(x.reshape(x.shape[0], -1)) # (batch, backcast length * feature_dim) -> (batch, theta_dim)
# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        # h -> theta -> backcast, forecast
        if self.mode == 'residual':# We can simply call pairplot on our DataFrame for an automatic visual analysis 

            # residual block
            theta_b = self.theta_b(x).reshape(shape[0], shape[2], self.theta_dim)
            theta_f = self.theta_f(x).reshape(shape[0], shape[2], self.theta_dim)
            b = self.linear_b(theta_b).permute(0,2,1) # (batch, backcast length, feature_dim)
            f = self.linear_f(theta_f).permute(0,2,1) # (batch, forecast length, feature_dim)
        else:
            theta_b = self.theta(x).reshape(shape[0], self.theta_dim, shape[2])
            theta_f = theta_b

            if self.mode == 'trend':
                b = self.get_trend(theta_b, t_b)
                f = self.get_trend(theta_f, t_f)
                
            elif self.mode == 'seasonality':
                b = self.get_seasonality(theta_b, t_b)
                f = self.get_seasonality(theta_f, t_f)
        return b, f# We can simply call pairplot on our DataFrame for an automatic visual analysis 


    def get_trend(self, theta, t):
        # theta dim = 0 -> 수평선 (y=a)
        # theta dim = 1 -> 직선 (y=bx)
        # theta dim = 2 -> 이차곡선 (y=cx^2)
        # ...
        T = torch.stack([t ** i for i in range(theta.shape[1])])  # (theta_dim ,sequence length)
        out = torch.einsum('btf,ts->bsf', theta, T)
        return out


    def get_seasonality(self, theta, t):
        # import pdb; pdb.set_trace() 
        s1 = torch.stack([torch.cos(2 * np.pi * (i+1) * t) for i in range(self.theta_dim//2)]).float()  # H/2-1
        s2 = torch.stack([torch.sin(2 * np.pi * (i+1) * t) for i in range(self.theta_dim//2)]).float()
        S = torch.cat([s1, s2])# We can simply call pairplot on our DataFrame for an automatic visual analysis 

        out = torch.einsum('btf,ts->bsf', theta, S)
        return out

# %%
model = NBeatsNet(forecast_length, backcast_length, theta_dim, n_trend, n_seasonality, n_residual, hidden_dim)
model = model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ### Train

# %%
import time
train_losses = []
val_losses = []
best_epoch = 0
start_time = time.time()
best_model_state_dict = None
best_val_loss = 10000
models = []
for k in range(35):
    model = NBeatsNet(forecast_length, backcast_length, theta_dim, n_trend, n_seasonality, n_residual, hidden_dim)
    model = model.cuda()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    for epoch in range(num_epoch):
        train_loss_mean = 0
        val_loss_mean = 0

        # train
        model.train()
        for i, (inputs, labels) in enumerate(train_loaders[k]):


            inputs = inputs.cuda()
            labels = labels.cuda()


            # forecast = model(inputs)

            backcast, forecast = model(inputs.unsqueeze(2))
            # import pdb; pdb.set_trace()
            loss = criterion(backcast.sum(0), inputs.unsqueeze(2)) + criterion(forecast.sum(0), labels.unsqueeze(2))
            #summation을 해주는 부분이다. 
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss_mean += loss.item()

            if i % 100 == 0:# We can simply call pairplot on our DataFrame for an automatic visual analysis 

                print('load [{}] epoch [{}/{}] iter [{:03d}/{:03d}] loss [{:.4f}] elapsed time [{:.2f}min]'.format(k,epoch, num_epoch, i, len(train_dataloader), loss.item(), (time.time()-start_time)/60))

        train_loss_mean = train_loss_mean/len(train_dataloader)
        wandb.log({
            f'train_loss_mean_{k}' : train_loss_mean
        })

        train_losses.append(train_loss_mean)

        # validation
        model.eval()
        with torch.no_grad():
            for i, (inputs, labels) in enumerate(val_loaders[k]):
                inputs = inputs.cuda()
                labels = labels.cuda()

                backcast, forecast = model(inputs.unsqueeze(2))
                loss = criterion(backcast.sum(0), inputs.unsqueeze(2)) + criterion(forecast.sum(0), labels.unsqueeze(2))
                val_loss_mean += loss.item()

            val_loss_mean = val_loss_mean/len(val_dataloader)
            wandb.log({
                f'val_loss_mean_{k}': val_loss_mean,
            })

            print('load [{}] epoch [{}/{}] train loss [{:.4f}] validation loss [{:.4f}] elapsed time [{:.2f} min]\n'.format(k, epoch, num_epoch, train_loss_mean, val_loss_mean, (time.time()-start_time)/60))

            if val_loss_mean < best_val_loss:
                best_epoch = epoch
                best_val_loss = val_loss_mean
                best_model_state_dict = model.state_dict()
        val_losses.append(val_loss_mean)
    models.append(model)
# Out:
# load [0] epoch [0/100] iter [000/736] loss [138690412544.0000] elapsed time [0.00min]
# load [0] epoch [0/100] iter [100/736] loss [4892340224.0000] elapsed time [0.07min]
# load [0] epoch [0/100] iter [200/736] loss [4354354176.0000] elapsed time [0.14min]
# load [0] epoch [0/100] iter [300/736] loss [16841924608.0000] elapsed time [0.20min]
# load [0] epoch [0/100] iter [400/736] loss [9734441984.0000] elapsed time [0.27min]
# load [0] epoch [0/100] iter [500/736] loss [3283765760.0000] elapsed time [0.34min]
# load [0] epoch [0/100] iter [600/736] loss [5200433664.0000] elapsed time [0.41min]
# load [0] epoch [0/100] iter [700/736] loss [5234513920.0000] elapsed time [0.48min]
# load [0] epoch [0/100] train loss [8270050918.9565] validation loss [3082497024.0000] elapsed time [0.51 min]
#
# load [0] epoch [1/100] iter [000/736] loss [3763551232.0000] elapsed time [0.51min]
# load [0] epoch [1/100] iter [100/736] loss [3585376512.0000] elapsed time [0.58min]
# load [0] epoch [1/100] iter [200/736] loss [7470941696.0000] elapsed time [0.64min]
# load [0] epoch [1/100] iter [300/736] loss [6558892032.0000] elapsed time [0.71min]
# load [0] epoch [1/100] iter [400/736] loss [3076358144.0000] elapsed time [0.78min]
# load [0] epoch [1/100] iter [500/736] loss [7868396544.0000] elapsed time [0.84min]
# load [0] epoch [1/100] iter [600/736] loss [7448731648.0000] elapsed time [0.91min]
# load [0] epoch [1/100] iter [700/736] loss [3167406080.0000] elapsed time [0.98min]
# load [0] epoch [1/100] train loss [5221741058.4348] validation loss [3173978112.0000] elapsed time [1.01 min]
#
# load [0] epoch [2/100] iter [000/736] loss [5759928320.0000] elapsed time [1.01min]
# load [0] epoch [2/100] iter [100/736] loss [3737584896.0000] elapsed time [1.08min]
# load [0] epoch [2/100] iter [200/736] loss [6619627520.0000] elapsed time [1.14min]
# load [0] epoch [2/100] iter [300/736] loss [9662722048.0000] elapsed time [1.20min]
# load [0] epoch [2/100] iter [400/736] loss [5036112384.0000] elapsed time [1.27min]
# load [0] epoch [2/100] iter [500/736] loss [4237134848.0000] elapsed time [1.34min]
# load [0] epoch [2/100] iter [600/736] loss [2975300608.0000] elapsed time [1.40min]
# load [0] epoch [2/100] iter [700/736] loss [4697067008.0000] elapsed time [1.47min]
# load [0] epoch [2/100] train loss [4986370509.5652] validation loss [2566330112.0000] elapsed time [1.49 min]
#
# load [0] epoch [3/100] iter [000/736] loss [3542899200.0000] elapsed time [1.50min]
# load [0] epoch [3/100] iter [100/736] loss [2989044736.0000] elapsed time [1.56min]
# load [0] epoch [3/100] iter [200/736] loss [3741240832.0000] elapsed time [1.63min]
# load [0] epoch [3/100] iter [300/736] loss [3545298944.0000] elapsed time [1.70min]
# load [0] epoch [3/100] iter [400/736] loss [3082304512.0000] elapsed time [1.76min]
# load [0] epoch [3/100] iter [500/736] loss [5291181568.0000] elapsed time [1.83min]
# load [0] epoch [3/100] iter [600/736] loss [3420569600.0000] elapsed time [1.90min]
# load [0] epoch [3/100] iter [700/736] loss [3495909376.0000] elapsed time [1.97min]
# load [0] epoch [3/100] train loss [4782695800.6957] validation loss [2924643584.0000] elapsed time [1.99 min]
#
# load [0] epoch [4/100] iter [000/736] loss [4848660480.0000] elapsed time [2.00min]
# load [0] epoch [4/100] iter [100/736] loss [5623870464.0000] elapsed time [2.06min]
# load [0] epoch [4/100] iter [200/736] loss [5442531328.0000] elapsed time [2.13min]
# load [0] epoch [4/100] iter [300/736] loss [6664523776.0000] elapsed time [2.19min]
# load [0] epoch [4/100] iter [400/736] loss [3079627008.0000] elapsed time [2.26min]
# load [0] epoch [4/100] iter [500/736] loss [3260847616.0000] elapsed time [2.33min]
# load [0] epoch [4/100] iter [600/736] loss [2949292032.0000] elapsed time [2.39min]
# load [0] epoch [4/100] iter [700/736] loss [2764805632.0000] elapsed time [2.46min]
# load [0] epoch [4/100] train loss [4631885794.0870] validation loss [2504274944.0000] elapsed time [2.48 min]
#
# load [0] epoch [5/100] iter [000/736] loss [2650810368.0000] elapsed time [2.49min]
# load [0] epoch [5/100] iter [100/736] loss [3434643200.0000] elapsed time [2.55min]
# load [0] epoch [5/100] iter [200/736] loss [6520416768.0000] elapsed time [2.62min]
# load [0] epoch [5/100] iter [300/736] loss [2974412800.0000] elapsed time [2.68min]
# load [0] epoch [5/100] iter [400/736] loss [2772863232.0000] elapsed time [2.75min]
# load [0] epoch [5/100] iter [500/736] loss [3256868864.0000] elapsed time [2.81min]
# load [0] epoch [5/100] iter [600/736] loss [7368445440.0000] elapsed time [2.88min]
# load [0] epoch [5/100] iter [700/736] loss [2988115968.0000] elapsed time [2.93min]
# load [0] epoch [5/100] train loss [4482609683.1304] validation loss [2662107648.0000] elapsed time [2.96 min]
#
# load [0] epoch [6/100] iter [000/736] loss [3184514560.0000] elapsed time [2.96min]
# load [0] epoch [6/100] iter [100/736] loss [4615636992.0000] elapsed time [3.02min]
# load [0] epoch [6/100] iter [200/736] loss [2926845952.0000] elapsed time [3.07min]
# load [0] epoch [6/100] iter [300/736] loss [2846784512.0000] elapsed time [3.13min]
# load [0] epoch [6/100] iter [400/736] loss [2753963520.0000] elapsed time [3.20min]
# load [0] epoch [6/100] iter [500/736] loss [3755286784.0000] elapsed time [3.27min]
# load [0] epoch [6/100] iter [600/736] loss [2771741696.0000] elapsed time [3.33min]
# load [0] epoch [6/100] iter [700/736] loss [2660543744.0000] elapsed time [3.40min]
# load [0] epoch [6/100] train loss [4291605008.6957] validation loss [2831517696.0000] elapsed time [3.43 min]
#
# load [0] epoch [7/100] iter [000/736] loss [3190284800.0000] elapsed time [3.43min]
# load [0] epoch [7/100] iter [100/736] loss [6308293632.0000] elapsed time [3.49min]
# load [0] epoch [7/100] iter [200/736] loss [3349146624.0000] elapsed time [3.56min]
# load [0] epoch [7/100] iter [300/736] loss [7368423424.0000] elapsed time [3.63min]
# load [0] epoch [7/100] iter [400/736] loss [4264806656.0000] elapsed time [3.69min]
# load [0] epoch [7/100] iter [500/736] loss [3818882048.0000] elapsed time [3.75min]
# load [0] epoch [7/100] iter [600/736] loss [5341161472.0000] elapsed time [3.81min]
# load [0] epoch [7/100] iter [700/736] loss [3198586112.0000] elapsed time [3.89min]
# load [0] epoch [7/100] train loss [4150064261.2174] validation loss [2825035008.0000] elapsed time [3.92 min]
#
# load [0] epoch [8/100] iter [000/736] loss [3267817984.0000] elapsed time [3.92min]
# load [0] epoch [8/100] iter [100/736] loss [3968285696.0000] elapsed time [3.99min]
# load [0] epoch [8/100] iter [200/736] loss [3499595264.0000] elapsed time [4.05min]
# load [0] epoch [8/100] iter [300/736] loss [2866797568.0000] elapsed time [4.12min]
# load [0] epoch [8/100] iter [400/736] loss [3209365504.0000] elapsed time [4.19min]
# load [0] epoch [8/100] iter [500/736] loss [3222245888.0000] elapsed time [4.25min]
# load [0] epoch [8/100] iter [600/736] loss [3883399168.0000] elapsed time [4.32min]
# load [0] epoch [8/100] iter [700/736] loss [3738632960.0000] elapsed time [4.39min]
# load [0] epoch [8/100] train loss [4000450460.1739] validation loss [2999760896.0000] elapsed time [4.41 min]
#
# load [0] epoch [9/100] iter [000/736] loss [3299152384.0000] elapsed time [4.42min]
# load [0] epoch [9/100] iter [100/736] loss [3321728256.0000] elapsed time [4.49min]
# load [0] epoch [9/100] iter [200/736] loss [2808220160.0000] elapsed time [4.56min]
# load [0] epoch [9/100] iter [300/736] loss [3217478144.0000] elapsed time [4.63min]
# load [0] epoch [9/100] iter [400/736] loss [3070314240.0000] elapsed time [4.69min]
# load [0] epoch [9/100] iter [500/736] loss [3200943872.0000] elapsed time [4.76min]
# load [0] epoch [9/100] iter [600/736] loss [3428046848.0000] elapsed time [4.83min]
# load [0] epoch [9/100] iter [700/736] loss [3245233152.0000] elapsed time [4.89min]
# load [0] epoch [9/100] train loss [3824877250.4348] validation loss [3833231616.0000] elapsed time [4.92 min]
#
# load [0] epoch [10/100] iter [000/736] loss [3613169664.0000] elapsed time [4.92min]
# load [0] epoch [10/100] iter [100/736] loss [5810066432.0000] elapsed time [4.99min]
# load [0] epoch [10/100] iter [200/736] loss [3157003776.0000] elapsed time [5.04min]
# load [0] epoch [10/100] iter [300/736] loss [3352231424.0000] elapsed time [5.08min]
# load [0] epoch [10/100] iter [400/736] loss [4157372672.0000] elapsed time [5.11min]
# load [0] epoch [10/100] iter [500/736] loss [5112000000.0000] elapsed time [5.16min]
# load [0] epoch [10/100] iter [600/736] loss [5085617664.0000] elapsed time [5.23min]
# load [0] epoch [10/100] iter [700/736] loss [3736919808.0000] elapsed time [5.30min]
# load [0] epoch [10/100] train loss [3704259361.0435] validation loss [2958348032.0000] elapsed time [5.32 min]
#
# load [0] epoch [11/100] iter [000/736] loss [2470132736.0000] elapsed time [5.33min]
# load [0] epoch [11/100] iter [100/736] loss [4233275904.0000] elapsed time [5.39min]
# load [0] epoch [11/100] iter [200/736] loss [4281978368.0000] elapsed time [5.46min]
# load [0] epoch [11/100] iter [300/736] loss [2420395520.0000] elapsed time [5.53min]
# load [0] epoch [11/100] iter [400/736] loss [2478679296.0000] elapsed time [5.60min]
# load [0] epoch [11/100] iter [500/736] loss [2785045504.0000] elapsed time [5.66min]
# load [0] epoch [11/100] iter [600/736] loss [3424911872.0000] elapsed time [5.73min]
# load [0] epoch [11/100] iter [700/736] loss [3806345216.0000] elapsed time [5.80min]
# load [0] epoch [11/100] train loss [3588639886.6087] validation loss [2854458624.0000] elapsed time [5.82 min]
#
# load [0] epoch [12/100] iter [000/736] loss [2764199168.0000] elapsed time [5.83min]
# load [0] epoch [12/100] iter [100/736] loss [4539577344.0000] elapsed time [5.89min]
# load [0] epoch [12/100] iter [200/736] loss [3134652672.0000] elapsed time [5.96min]
# load [0] epoch [12/100] iter [300/736] loss [3541317632.0000] elapsed time [6.03min]
# load [0] epoch [12/100] iter [400/736] loss [2825461760.0000] elapsed time [6.09min]
# load [0] epoch [12/100] iter [500/736] loss [3300120064.0000] elapsed time [6.16min]
# load [0] epoch [12/100] iter [600/736] loss [2650638336.0000] elapsed time [6.23min]
# load [0] epoch [12/100] iter [700/736] loss [3702585344.0000] elapsed time [6.29min]
# load [0] epoch [12/100] train loss [3474934182.9565] validation loss [3328291584.0000] elapsed time [6.32 min]
#
# load [0] epoch [13/100] iter [000/736] loss [2773690880.0000] elapsed time [6.32min]
# load [0] epoch [13/100] iter [100/736] loss [3140054784.0000] elapsed time [6.39min]
# load [0] epoch [13/100] iter [200/736] loss [3966002176.0000] elapsed time [6.46min]
# load [0] epoch [13/100] iter [300/736] loss [3832240128.0000] elapsed time [6.52min]
# load [0] epoch [13/100] iter [400/736] loss [2408188416.0000] elapsed time [6.59min]
# load [0] epoch [13/100] iter [500/736] loss [4009030144.0000] elapsed time [6.65min]
# load [0] epoch [13/100] iter [600/736] loss [2982280192.0000] elapsed time [6.72min]
# load [0] epoch [13/100] iter [700/736] loss [4525005824.0000] elapsed time [6.79min]
# load [0] epoch [13/100] train loss [3409298786.7826] validation loss [3157404928.0000] elapsed time [6.81 min]
#
# load [0] epoch [14/100] iter [000/736] loss [2448039680.0000] elapsed time [6.82min]
# load [0] epoch [14/100] iter [100/736] loss [2721690880.0000] elapsed time [6.88min]
# load [0] epoch [14/100] iter [200/736] loss [2736844288.0000] elapsed time [6.95min]
# load [0] epoch [14/100] iter [300/736] loss [3557815808.0000] elapsed time [7.02min]
# load [0] epoch [14/100] iter [400/736] loss [3766512384.0000] elapsed time [7.08min]
# load [0] epoch [14/100] iter [500/736] loss [2646106624.0000] elapsed time [7.15min]
# load [0] epoch [14/100] iter [600/736] loss [2616334336.0000] elapsed time [7.22min]
# load [0] epoch [14/100] iter [700/736] loss [2611363328.0000] elapsed time [7.28min]
# load [0] epoch [14/100] train loss [3403489973.2174] validation loss [3391544064.0000] elapsed time [7.31 min]
#
# load [0] epoch [15/100] iter [000/736] loss [3460907520.0000] elapsed time [7.31min]
# load [0] epoch [15/100] iter [100/736] loss [2325896704.0000] elapsed time [7.38min]
# load [0] epoch [15/100] iter [200/736] loss [2722088960.0000] elapsed time [7.45min]
# load [0] epoch [15/100] iter [300/736] loss [2825964032.0000] elapsed time [7.51min]
# load [0] epoch [15/100] iter [400/736] loss [2610856448.0000] elapsed time [7.58min]
# load [0] epoch [15/100] iter [500/736] loss [4073913856.0000] elapsed time [7.64min]
# load [0] epoch [15/100] iter [600/736] loss [3446808320.0000] elapsed time [7.71min]
# load [0] epoch [15/100] iter [700/736] loss [3173889024.0000] elapsed time [7.77min]
# load [0] epoch [15/100] train loss [3318814625.7391] validation loss [3587092480.0000] elapsed time [7.80 min]
#
# load [0] epoch [16/100] iter [000/736] loss [3136166400.0000] elapsed time [7.80min]
# load [0] epoch [16/100] iter [100/736] loss [2658328320.0000] elapsed time [7.87min]
# load [0] epoch [16/100] iter [200/736] loss [3150334976.0000] elapsed time [7.94min]
# load [0] epoch [16/100] iter [300/736] loss [2511733760.0000] elapsed time [8.02min]
# load [0] epoch [16/100] iter [400/736] loss [3967184384.0000] elapsed time [8.09min]
# load [0] epoch [16/100] iter [500/736] loss [4030556416.0000] elapsed time [8.16min]
# load [0] epoch [16/100] iter [600/736] loss [2517089280.0000] elapsed time [8.22min]
# load [0] epoch [16/100] iter [700/736] loss [2747569664.0000] elapsed time [8.29min]
# load [0] epoch [16/100] train loss [3282475564.8696] validation loss [3370464256.0000] elapsed time [8.32 min]
#
# load [0] epoch [17/100] iter [000/736] loss [3035326208.0000] elapsed time [8.32min]
# load [0] epoch [17/100] iter [100/736] loss [2406023424.0000] elapsed time [8.38min]
# load [0] epoch [17/100] iter [200/736] loss [5123818496.0000] elapsed time [8.45min]
# load [0] epoch [17/100] iter [300/736] loss [4167406592.0000] elapsed time [8.51min]
# load [0] epoch [17/100] iter [400/736] loss [3017238272.0000] elapsed time [8.58min]
# load [0] epoch [17/100] iter [500/736] loss [3440805376.0000] elapsed time [8.64min]
# load [0] epoch [17/100] iter [600/736] loss [3600535552.0000] elapsed time [8.71min]
# load [0] epoch [17/100] iter [700/736] loss [3013520384.0000] elapsed time [8.77min]
# load [0] epoch [17/100] train loss [3228903649.0435] validation loss [3701894144.0000] elapsed time [8.80 min]
#
# load [0] epoch [18/100] iter [000/736] loss [2607866368.0000] elapsed time [8.80min]
# load [0] epoch [18/100] iter [100/736] loss [4455655936.0000] elapsed time [8.87min]
# load [0] epoch [18/100] iter [200/736] loss [3224846336.0000] elapsed time [8.94min]
# load [0] epoch [18/100] iter [300/736] loss [3544332288.0000] elapsed time [9.00min]
# load [0] epoch [18/100] iter [400/736] loss [2511578624.0000] elapsed time [9.07min]
# load [0] epoch [18/100] iter [500/736] loss [3456058624.0000] elapsed time [9.14min]
# load [0] epoch [18/100] iter [600/736] loss [3644888320.0000] elapsed time [9.20min]
# load [0] epoch [18/100] iter [700/736] loss [2704123648.0000] elapsed time [9.27min]
# load [0] epoch [18/100] train loss [3157215633.3913] validation loss [3657401088.0000] elapsed time [9.29 min]
#
# load [0] epoch [19/100] iter [000/736] loss [2492238848.0000] elapsed time [9.30min]
# load [0] epoch [19/100] iter [100/736] loss [3502182656.0000] elapsed time [9.36min]
# load [0] epoch [19/100] iter [200/736] loss [2959236096.0000] elapsed time [9.43min]
# load [0] epoch [19/100] iter [300/736] loss [2840495104.0000] elapsed time [9.49min]
# load [0] epoch [19/100] iter [400/736] loss [2891381248.0000] elapsed time [9.56min]
# load [0] epoch [19/100] iter [500/736] loss [2976866048.0000] elapsed time [9.63min]
# load [0] epoch [19/100] iter [600/736] loss [3661991936.0000] elapsed time [9.70min]
# load [0] epoch [19/100] iter [700/736] loss [3537350144.0000] elapsed time [9.76min]
# load [0] epoch [19/100] train loss [3091636181.2174] validation loss [3881163520.0000] elapsed time [9.79 min]
#
# load [0] epoch [20/100] iter [000/736] loss [3104403968.0000] elapsed time [9.79min]
# load [0] epoch [20/100] iter [100/736] loss [2444744192.0000] elapsed time [9.86min]
# load [0] epoch [20/100] iter [200/736] loss [2550650368.0000] elapsed time [9.93min]
# load [0] epoch [20/100] iter [300/736] loss [4434696192.0000] elapsed time [9.99min]
# load [0] epoch [20/100] iter [400/736] loss [3255375872.0000] elapsed time [10.06min]
# load [0] epoch [20/100] iter [500/736] loss [3729501952.0000] elapsed time [10.12min]
# load [0] epoch [20/100] iter [600/736] loss [2901157376.0000] elapsed time [10.19min]
# load [0] epoch [20/100] iter [700/736] loss [2408084224.0000] elapsed time [10.26min]
# load [0] epoch [20/100] train loss [3060638350.7826] validation loss [3285095936.0000] elapsed time [10.29 min]
#
# load [0] epoch [21/100] iter [000/736] loss [2959014400.0000] elapsed time [10.29min]
# load [0] epoch [21/100] iter [100/736] loss [4311788032.0000] elapsed time [10.35min]
# load [0] epoch [21/100] iter [200/736] loss [3567717632.0000] elapsed time [10.42min]
# load [0] epoch [21/100] iter [300/736] loss [2417116672.0000] elapsed time [10.49min]
# load [0] epoch [21/100] iter [400/736] loss [3530923008.0000] elapsed time [10.56min]
# load [0] epoch [21/100] iter [500/736] loss [2910059008.0000] elapsed time [10.62min]
# load [0] epoch [21/100] iter [600/736] loss [3879225856.0000] elapsed time [10.69min]
# load [0] epoch [21/100] iter [700/736] loss [2601700864.0000] elapsed time [10.75min]
# load [0] epoch [21/100] train loss [3040313694.6087] validation loss [4364382720.0000] elapsed time [10.78 min]
#
# load [0] epoch [22/100] iter [000/736] loss [4111902208.0000] elapsed time [10.79min]
# load [0] epoch [22/100] iter [100/736] loss [3148727808.0000] elapsed time [10.85min]
# load [0] epoch [22/100] iter [200/736] loss [3113950208.0000] elapsed time [10.92min]
# load [0] epoch [22/100] iter [300/736] loss [2765504512.0000] elapsed time [10.99min]
# load [0] epoch [22/100] iter [400/736] loss [2955072000.0000] elapsed time [11.06min]
# load [0] epoch [22/100] iter [500/736] loss [2895129600.0000] elapsed time [11.13min]
# load [0] epoch [22/100] iter [600/736] loss [3020428288.0000] elapsed time [11.20min]
# load [0] epoch [22/100] iter [700/736] loss [2394953216.0000] elapsed time [11.27min]
# load [0] epoch [22/100] train loss [3039363389.2174] validation loss [3596831232.0000] elapsed time [11.29 min]
#
# load [0] epoch [23/100] iter [000/736] loss [2596275200.0000] elapsed time [11.30min]
# load [0] epoch [23/100] iter [100/736] loss [3717541376.0000] elapsed time [11.37min]
# load [0] epoch [23/100] iter [200/736] loss [3831107072.0000] elapsed time [11.43min]
# load [0] epoch [23/100] iter [300/736] loss [3320541696.0000] elapsed time [11.50min]
# load [0] epoch [23/100] iter [400/736] loss [2440734720.0000] elapsed time [11.57min]
# load [0] epoch [23/100] iter [500/736] loss [3107128832.0000] elapsed time [11.64min]
# load [0] epoch [23/100] iter [600/736] loss [3185948160.0000] elapsed time [11.70min]
# load [0] epoch [23/100] iter [700/736] loss [2617881088.0000] elapsed time [11.77min]
# load [0] epoch [23/100] train loss [2944945782.4348] validation loss [4720424960.0000] elapsed time [11.80 min]
#
# load [0] epoch [24/100] iter [000/736] loss [3616816128.0000] elapsed time [11.80min]
# load [0] epoch [24/100] iter [100/736] loss [3098308864.0000] elapsed time [11.87min]
# load [0] epoch [24/100] iter [200/736] loss [2827208960.0000] elapsed time [11.93min]
# load [0] epoch [24/100] iter [300/736] loss [3183331840.0000] elapsed time [12.00min]
# load [0] epoch [24/100] iter [400/736] loss [2501980160.0000] elapsed time [12.07min]
# load [0] epoch [24/100] iter [500/736] loss [3069179136.0000] elapsed time [12.13min]
# load [0] epoch [24/100] iter [600/736] loss [2869993984.0000] elapsed time [12.20min]
# load [0] epoch [24/100] iter [700/736] loss [3305740800.0000] elapsed time [12.25min]
# load [0] epoch [24/100] train loss [2923056141.2174] validation loss [3297472000.0000] elapsed time [12.28 min]
#
# load [0] epoch [25/100] iter [000/736] loss [3149209600.0000] elapsed time [12.28min]
# load [0] epoch [25/100] iter [100/736] loss [2540432384.0000] elapsed time [12.34min]
# load [0] epoch [25/100] iter [200/736] loss [3176010752.0000] elapsed time [12.41min]
# load [0] epoch [25/100] iter [300/736] loss [3187948544.0000] elapsed time [12.48min]
# load [0] epoch [25/100] iter [400/736] loss [2331020288.0000] elapsed time [12.54min]
# load [0] epoch [25/100] iter [500/736] loss [4101672448.0000] elapsed time [12.57min]
# load [0] epoch [25/100] iter [600/736] loss [2945846528.0000] elapsed time [12.64min]
# load [0] epoch [25/100] iter [700/736] loss [2688259072.0000] elapsed time [12.69min]
# load [0] epoch [25/100] train loss [2923628332.0000] validation loss [2906957824.0000] elapsed time [12.72 min]
#
# load [0] epoch [26/100] iter [000/736] loss [2806292480.0000] elapsed time [12.72min]
# load [0] epoch [26/100] iter [100/736] loss [2859450624.0000] elapsed time [12.79min]
# load [0] epoch [26/100] iter [200/736] loss [3307570944.0000] elapsed time [12.86min]
# load [0] epoch [26/100] iter [300/736] loss [2254273280.0000] elapsed time [12.93min]
# load [0] epoch [26/100] iter [400/736] loss [3084455680.0000] elapsed time [12.99min]
# load [0] epoch [26/100] iter [500/736] loss [2698290176.0000] elapsed time [13.06min]
# load [0] epoch [26/100] iter [600/736] loss [4613915136.0000] elapsed time [13.13min]
# load [0] epoch [26/100] iter [700/736] loss [2531327488.0000] elapsed time [13.20min]
# load [0] epoch [26/100] train loss [2875095478.0870] validation loss [3515994112.0000] elapsed time [13.22 min]
#
# load [0] epoch [27/100] iter [000/736] loss [3063505920.0000] elapsed time [13.23min]
# load [0] epoch [27/100] iter [100/736] loss [2394569472.0000] elapsed time [13.28min]
# load [0] epoch [27/100] iter [200/736] loss [2857205760.0000] elapsed time [13.36min]
# load [0] epoch [27/100] iter [300/736] loss [3469500416.0000] elapsed time [13.43min]
# load [0] epoch [27/100] iter [400/736] loss [2532125184.0000] elapsed time [13.50min]
# load [0] epoch [27/100] iter [500/736] loss [2357134848.0000] elapsed time [13.57min]
# load [0] epoch [27/100] iter [600/736] loss [2175589120.0000] elapsed time [13.63min]
# load [0] epoch [27/100] iter [700/736] loss [3186691328.0000] elapsed time [13.70min]
# load [0] epoch [27/100] train loss [2818998976.3478] validation loss [4494412288.0000] elapsed time [13.73 min]
#
# load [0] epoch [28/100] iter [000/736] loss [3666618880.0000] elapsed time [13.73min]
# load [0] epoch [28/100] iter [100/736] loss [3036387072.0000] elapsed time [13.80min]
# load [0] epoch [28/100] iter [200/736] loss [2884734976.0000] elapsed time [13.86min]
# load [0] epoch [28/100] iter [300/736] loss [2668172544.0000] elapsed time [13.93min]
# load [0] epoch [28/100] iter [400/736] loss [3692703744.0000] elapsed time [14.00min]
# load [0] epoch [28/100] iter [500/736] loss [3239053312.0000] elapsed time [14.06min]
# load [0] epoch [28/100] iter [600/736] loss [2480128256.0000] elapsed time [14.13min]
# load [0] epoch [28/100] iter [700/736] loss [2589172992.0000] elapsed time [14.20min]
# load [0] epoch [28/100] train loss [2785407234.0870] validation loss [4496318976.0000] elapsed time [14.22 min]
#
# load [0] epoch [29/100] iter [000/736] loss [2840630784.0000] elapsed time [14.22min]
# load [0] epoch [29/100] iter [100/736] loss [2796428288.0000] elapsed time [14.29min]
# load [0] epoch [29/100] iter [200/736] loss [2779842304.0000] elapsed time [14.36min]
# load [0] epoch [29/100] iter [300/736] loss [2502348800.0000] elapsed time [14.42min]
# load [0] epoch [29/100] iter [400/736] loss [3107316736.0000] elapsed time [14.49min]
# load [0] epoch [29/100] iter [500/736] loss [3934440448.0000] elapsed time [14.56min]
# load [0] epoch [29/100] iter [600/736] loss [2173876736.0000] elapsed time [14.62min]
# load [0] epoch [29/100] iter [700/736] loss [2414633216.0000] elapsed time [14.69min]
# load [0] epoch [29/100] train loss [2804086828.6957] validation loss [4315294208.0000] elapsed time [14.72 min]
#
# load [0] epoch [30/100] iter [000/736] loss [2312959744.0000] elapsed time [14.72min]
# load [0] epoch [30/100] iter [100/736] loss [3198168064.0000] elapsed time [14.78min]
# load [0] epoch [30/100] iter [200/736] loss [2099169536.0000] elapsed time [14.85min]
# load [0] epoch [30/100] iter [300/736] loss [2427518208.0000] elapsed time [14.92min]
# load [0] epoch [30/100] iter [400/736] loss [3306716160.0000] elapsed time [14.99min]
# load [0] epoch [30/100] iter [500/736] loss [3426086656.0000] elapsed time [15.06min]
# load [0] epoch [30/100] iter [600/736] loss [2397394944.0000] elapsed time [15.13min]
# load [0] epoch [30/100] iter [700/736] loss [1900088448.0000] elapsed time [15.20min]
# load [0] epoch [30/100] train loss [2771240537.9130] validation loss [3717871104.0000] elapsed time [15.23 min]
#
# load [0] epoch [31/100] iter [000/736] loss [2676233216.0000] elapsed time [15.23min]
# load [0] epoch [31/100] iter [100/736] loss [2485107200.0000] elapsed time [15.30min]
# load [0] epoch [31/100] iter [200/736] loss [2513179648.0000] elapsed time [15.37min]
# load [0] epoch [31/100] iter [300/736] loss [2759491072.0000] elapsed time [15.44min]
# load [0] epoch [31/100] iter [400/736] loss [2573111296.0000] elapsed time [15.52min]
# load [0] epoch [31/100] iter [500/736] loss [2506032384.0000] elapsed time [15.59min]
# load [0] epoch [31/100] iter [600/736] loss [2879522304.0000] elapsed time [15.65min]
# load [0] epoch [31/100] iter [700/736] loss [2356861952.0000] elapsed time [15.72min]
# load [0] epoch [31/100] train loss [2707101943.4783] validation loss [4926192640.0000] elapsed time [15.75 min]
#
# load [0] epoch [32/100] iter [000/736] loss [2112173568.0000] elapsed time [15.75min]
# load [0] epoch [32/100] iter [100/736] loss [2692130816.0000] elapsed time [15.82min]
# load [0] epoch [32/100] iter [200/736] loss [2107423872.0000] elapsed time [15.89min]
# load [0] epoch [32/100] iter [300/736] loss [2810823680.0000] elapsed time [15.95min]
# load [0] epoch [32/100] iter [400/736] loss [2442416640.0000] elapsed time [16.02min]
# load [0] epoch [32/100] iter [500/736] loss [2438730240.0000] elapsed time [16.08min]
# load [0] epoch [32/100] iter [600/736] loss [2790222336.0000] elapsed time [16.16min]
# load [0] epoch [32/100] iter [700/736] loss [2155908608.0000] elapsed time [16.22min]
# load [0] epoch [32/100] train loss [2680866206.6087] validation loss [4351979520.0000] elapsed time [16.25 min]
#
# load [0] epoch [33/100] iter [000/736] loss [3281132800.0000] elapsed time [16.25min]
# load [0] epoch [33/100] iter [100/736] loss [2037862400.0000] elapsed time [16.32min]
# load [0] epoch [33/100] iter [200/736] loss [2599284992.0000] elapsed time [16.38min]
# load [0] epoch [33/100] iter [300/736] loss [2496044544.0000] elapsed time [16.45min]
# load [0] epoch [33/100] iter [400/736] loss [3402926336.0000] elapsed time [16.51min]
# load [0] epoch [33/100] iter [500/736] loss [2500201728.0000] elapsed time [16.58min]
# load [0] epoch [33/100] iter [600/736] loss [2198155008.0000] elapsed time [16.64min]
# load [0] epoch [33/100] iter [700/736] loss [2715199744.0000] elapsed time [16.70min]
# load [0] epoch [33/100] train loss [2679811867.1304] validation loss [5593953280.0000] elapsed time [16.73 min]
#
# load [0] epoch [34/100] iter [000/736] loss [2601952256.0000] elapsed time [16.73min]
# load [0] epoch [34/100] iter [100/736] loss [2430677504.0000] elapsed time [16.79min]
# load [0] epoch [34/100] iter [200/736] loss [2628467200.0000] elapsed time [16.85min]
# load [0] epoch [34/100] iter [300/736] loss [2260724480.0000] elapsed time [16.91min]
# load [0] epoch [34/100] iter [400/736] loss [2323370496.0000] elapsed time [16.98min]
# load [0] epoch [34/100] iter [500/736] loss [2292270592.0000] elapsed time [17.05min]
# load [0] epoch [34/100] iter [600/736] loss [2380569600.0000] elapsed time [17.11min]
# load [0] epoch [34/100] iter [700/736] loss [2139247360.0000] elapsed time [17.17min]
# load [0] epoch [34/100] train loss [2645707950.0870] validation loss [4576283648.0000] elapsed time [17.20 min]
#
# load [0] epoch [35/100] iter [000/736] loss [2058171136.0000] elapsed time [17.20min]
# load [0] epoch [35/100] iter [100/736] loss [2348794368.0000] elapsed time [17.27min]
# load [0] epoch [35/100] iter [200/736] loss [2187043840.0000] elapsed time [17.33min]
# load [0] epoch [35/100] iter [300/736] loss [3405802496.0000] elapsed time [17.40min]
# load [0] epoch [35/100] iter [400/736] loss [3325599744.0000] elapsed time [17.47min]
# load [0] epoch [35/100] iter [500/736] loss [2344214784.0000] elapsed time [17.53min]
# load [0] epoch [35/100] iter [600/736] loss [2484419072.0000] elapsed time [17.60min]
# load [0] epoch [35/100] iter [700/736] loss [2237974272.0000] elapsed time [17.66min]
# load [0] epoch [35/100] train loss [2608449297.5652] validation loss [4877647872.0000] elapsed time [17.69 min]
#
# load [0] epoch [36/100] iter [000/736] loss [2915767296.0000] elapsed time [17.70min]
# load [0] epoch [36/100] iter [100/736] loss [3029577472.0000] elapsed time [17.76min]
# load [0] epoch [36/100] iter [200/736] loss [2374611456.0000] elapsed time [17.83min]
# load [0] epoch [36/100] iter [300/736] loss [2315158528.0000] elapsed time [17.89min]
# load [0] epoch [36/100] iter [400/736] loss [2165789952.0000] elapsed time [17.95min]
# load [0] epoch [36/100] iter [500/736] loss [2227370496.0000] elapsed time [18.02min]
# load [0] epoch [36/100] iter [600/736] loss [3006692352.0000] elapsed time [18.09min]
# load [0] epoch [36/100] iter [700/736] loss [2253284864.0000] elapsed time [18.16min]
# load [0] epoch [36/100] train loss [2599638899.1304] validation loss [4879559168.0000] elapsed time [18.19 min]
#
# load [0] epoch [37/100] iter [000/736] loss [2214587136.0000] elapsed time [18.19min]
# load [0] epoch [37/100] iter [100/736] loss [2748560640.0000] elapsed time [18.26min]
# load [0] epoch [37/100] iter [200/736] loss [3374397184.0000] elapsed time [18.32min]
# load [0] epoch [37/100] iter [300/736] loss [3252384256.0000] elapsed time [18.39min]
# load [0] epoch [37/100] iter [400/736] loss [2260998400.0000] elapsed time [18.45min]
# load [0] epoch [37/100] iter [500/736] loss [2468738816.0000] elapsed time [18.52min]
# load [0] epoch [37/100] iter [600/736] loss [2758154496.0000] elapsed time [18.58min]
# load [0] epoch [37/100] iter [700/736] loss [2752174080.0000] elapsed time [18.65min]
# load [0] epoch [37/100] train loss [2602760959.8261] validation loss [4409465344.0000] elapsed time [18.68 min]
#
# load [0] epoch [38/100] iter [000/736] loss [2435184640.0000] elapsed time [18.68min]
# load [0] epoch [38/100] iter [100/736] loss [2818050048.0000] elapsed time [18.75min]
# load [0] epoch [38/100] iter [200/736] loss [3766875392.0000] elapsed time [18.81min]
# load [0] epoch [38/100] iter [300/736] loss [2231430400.0000] elapsed time [18.88min]
# load [0] epoch [38/100] iter [400/736] loss [2882999040.0000] elapsed time [18.94min]
# load [0] epoch [38/100] iter [500/736] loss [2418276096.0000] elapsed time [19.01min]
# load [0] epoch [38/100] iter [600/736] loss [2147576064.0000] elapsed time [19.08min]
# load [0] epoch [38/100] iter [700/736] loss [2143990144.0000] elapsed time [19.15min]
# load [0] epoch [38/100] train loss [2582922167.1304] validation loss [5564414976.0000] elapsed time [19.17 min]
#
# load [0] epoch [39/100] iter [000/736] loss [3106185728.0000] elapsed time [19.18min]
# load [0] epoch [39/100] iter [100/736] loss [2916167936.0000] elapsed time [19.24min]
# load [0] epoch [39/100] iter [200/736] loss [2770603008.0000] elapsed time [19.31min]
# load [0] epoch [39/100] iter [300/736] loss [2601849344.0000] elapsed time [19.38min]
# load [0] epoch [39/100] iter [400/736] loss [2049046784.0000] elapsed time [19.44min]
# load [0] epoch [39/100] iter [500/736] loss [2501412608.0000] elapsed time [19.51min]
# load [0] epoch [39/100] iter [600/736] loss [2816239616.0000] elapsed time [19.57min]
# load [0] epoch [39/100] iter [700/736] loss [2342042624.0000] elapsed time [19.64min]
# load [0] epoch [39/100] train loss [2528481465.5652] validation loss [4110630912.0000] elapsed time [19.67 min]
#
# load [0] epoch [40/100] iter [000/736] loss [2357863424.0000] elapsed time [19.67min]
# load [0] epoch [40/100] iter [100/736] loss [2165832448.0000] elapsed time [19.74min]
# load [0] epoch [40/100] iter [200/736] loss [2543451136.0000] elapsed time [19.80min]
# load [0] epoch [40/100] iter [300/736] loss [1888391936.0000] elapsed time [19.87min]
# load [0] epoch [40/100] iter [400/736] loss [2112742144.0000] elapsed time [19.93min]
# load [0] epoch [40/100] iter [500/736] loss [2019639296.0000] elapsed time [20.00min]
# load [0] epoch [40/100] iter [600/736] loss [3131100160.0000] elapsed time [20.07min]
# load [0] epoch [40/100] iter [700/736] loss [3074730240.0000] elapsed time [20.13min]
# load [0] epoch [40/100] train loss [2517117500.5217] validation loss [5094925312.0000] elapsed time [20.16 min]
#
# load [0] epoch [41/100] iter [000/736] loss [2464461312.0000] elapsed time [20.17min]
# load [0] epoch [41/100] iter [100/736] loss [2055321216.0000] elapsed time [20.24min]
# load [0] epoch [41/100] iter [200/736] loss [3617992960.0000] elapsed time [20.30min]
# load [0] epoch [41/100] iter [300/736] loss [2282941440.0000] elapsed time [20.37min]
# load [0] epoch [41/100] iter [400/736] loss [3209714944.0000] elapsed time [20.44min]
# load [0] epoch [41/100] iter [500/736] loss [2228253184.0000] elapsed time [20.50min]
# load [0] epoch [41/100] iter [600/736] loss [3167854080.0000] elapsed time [20.57min]
# load [0] epoch [41/100] iter [700/736] loss [3489428224.0000] elapsed time [20.63min]
# load [0] epoch [41/100] train loss [2506128807.6522] validation loss [5090878464.0000] elapsed time [20.66 min]
#
# load [0] epoch [42/100] iter [000/736] loss [2238273536.0000] elapsed time [20.67min]
# load [0] epoch [42/100] iter [100/736] loss [1945191040.0000] elapsed time [20.73min]
# load [0] epoch [42/100] iter [200/736] loss [2776091136.0000] elapsed time [20.80min]
# load [0] epoch [42/100] iter [300/736] loss [2230229760.0000] elapsed time [20.87min]
# load [0] epoch [42/100] iter [400/736] loss [2104851456.0000] elapsed time [20.93min]
# load [0] epoch [42/100] iter [500/736] loss [2186713600.0000] elapsed time [21.00min]
# load [0] epoch [42/100] iter [600/736] loss [3031275264.0000] elapsed time [21.07min]
# load [0] epoch [42/100] iter [700/736] loss [1909034112.0000] elapsed time [21.13min]
# load [0] epoch [42/100] train loss [2486949732.0000] validation loss [5455033344.0000] elapsed time [21.16 min]
#
# load [0] epoch [43/100] iter [000/736] loss [1853220864.0000] elapsed time [21.16min]
# load [0] epoch [43/100] iter [100/736] loss [3269044480.0000] elapsed time [21.23min]
# load [0] epoch [43/100] iter [200/736] loss [2265963008.0000] elapsed time [21.29min]
# load [0] epoch [43/100] iter [300/736] loss [1901926144.0000] elapsed time [21.36min]
# load [0] epoch [43/100] iter [400/736] loss [2127798528.0000] elapsed time [21.43min]
# load [0] epoch [43/100] iter [500/736] loss [2704727808.0000] elapsed time [21.49min]
# load [0] epoch [43/100] iter [600/736] loss [2002913536.0000] elapsed time [21.56min]
# load [0] epoch [43/100] iter [700/736] loss [2243322368.0000] elapsed time [21.62min]
# load [0] epoch [43/100] train loss [2459112656.3478] validation loss [5322994176.0000] elapsed time [21.65 min]
#
# load [0] epoch [44/100] iter [000/736] loss [2554539008.0000] elapsed time [21.65min]
# load [0] epoch [44/100] iter [100/736] loss [3207390208.0000] elapsed time [21.72min]
# load [0] epoch [44/100] iter [200/736] loss [2609496576.0000] elapsed time [21.79min]
# load [0] epoch [44/100] iter [300/736] loss [2871311360.0000] elapsed time [21.86min]
# load [0] epoch [44/100] iter [400/736] loss [2494530048.0000] elapsed time [21.92min]
# load [0] epoch [44/100] iter [500/736] loss [2343040000.0000] elapsed time [21.99min]
# load [0] epoch [44/100] iter [600/736] loss [2091879680.0000] elapsed time [22.06min]
# load [0] epoch [44/100] iter [700/736] loss [2161059328.0000] elapsed time [22.12min]
# load [0] epoch [44/100] train loss [2454432516.6957] validation loss [4234361856.0000] elapsed time [22.15 min]
#
# load [0] epoch [45/100] iter [000/736] loss [2081170944.0000] elapsed time [22.15min]
# load [0] epoch [45/100] iter [100/736] loss [2668319744.0000] elapsed time [22.22min]
# load [0] epoch [45/100] iter [200/736] loss [2055547264.0000] elapsed time [22.29min]
# load [0] epoch [45/100] iter [300/736] loss [2741737472.0000] elapsed time [22.35min]
# load [0] epoch [45/100] iter [400/736] loss [2046483840.0000] elapsed time [22.42min]
# load [0] epoch [45/100] iter [500/736] loss [2650178048.0000] elapsed time [22.48min]
# load [0] epoch [45/100] iter [600/736] loss [2375000576.0000] elapsed time [22.55min]
# load [0] epoch [45/100] iter [700/736] loss [2192923136.0000] elapsed time [22.61min]
# load [0] epoch [45/100] train loss [2484006367.1304] validation loss [4823393280.0000] elapsed time [22.64 min]
#
# load [0] epoch [46/100] iter [000/736] loss [2045739648.0000] elapsed time [22.64min]
# load [0] epoch [46/100] iter [100/736] loss [2140631296.0000] elapsed time [22.71min]
# load [0] epoch [46/100] iter [200/736] loss [2480138496.0000] elapsed time [22.78min]
# load [0] epoch [46/100] iter [300/736] loss [2622871040.0000] elapsed time [22.84min]
# load [0] epoch [46/100] iter [400/736] loss [2275340544.0000] elapsed time [22.91min]
# load [0] epoch [46/100] iter [500/736] loss [2843862528.0000] elapsed time [22.97min]
# load [0] epoch [46/100] iter [600/736] loss [2063742208.0000] elapsed time [23.04min]
# load [0] epoch [46/100] iter [700/736] loss [2359958272.0000] elapsed time [23.11min]
# load [0] epoch [46/100] train loss [2413542134.0870] validation loss [4347887104.0000] elapsed time [23.14 min]
#
# load [0] epoch [47/100] iter [000/736] loss [3069658112.0000] elapsed time [23.14min]
# load [0] epoch [47/100] iter [100/736] loss [2259810560.0000] elapsed time [23.21min]
# load [0] epoch [47/100] iter [200/736] loss [1912570880.0000] elapsed time [23.28min]
# load [0] epoch [47/100] iter [300/736] loss [3590544384.0000] elapsed time [23.35min]
# load [0] epoch [47/100] iter [400/736] loss [1732069760.0000] elapsed time [23.42min]
# load [0] epoch [47/100] iter [500/736] loss [2449355776.0000] elapsed time [23.49min]
# load [0] epoch [47/100] iter [600/736] loss [2416769536.0000] elapsed time [23.54min]
# load [0] epoch [47/100] iter [700/736] loss [1852338816.0000] elapsed time [23.61min]
# load [0] epoch [47/100] train loss [2407900874.6087] validation loss [4606005760.0000] elapsed time [23.64 min]
#
# load [0] epoch [48/100] iter [000/736] loss [2273787904.0000] elapsed time [23.64min]
# load [0] epoch [48/100] iter [100/736] loss [2151798528.0000] elapsed time [23.71min]
# load [0] epoch [48/100] iter [200/736] loss [2231332096.0000] elapsed time [23.78min]
# load [0] epoch [48/100] iter [300/736] loss [2115736064.0000] elapsed time [23.84min]
# load [0] epoch [48/100] iter [400/736] loss [2811510528.0000] elapsed time [23.91min]
# load [0] epoch [48/100] iter [500/736] loss [2143141120.0000] elapsed time [23.98min]
# load [0] epoch [48/100] iter [600/736] loss [2041457664.0000] elapsed time [24.05min]
# load [0] epoch [48/100] iter [700/736] loss [2306800640.0000] elapsed time [24.12min]
# load [0] epoch [48/100] train loss [2388865492.3478] validation loss [4505505792.0000] elapsed time [24.15 min]
#
# load [0] epoch [49/100] iter [000/736] loss [2211317760.0000] elapsed time [24.15min]
# load [0] epoch [49/100] iter [100/736] loss [2482483712.0000] elapsed time [24.22min]
# load [0] epoch [49/100] iter [200/736] loss [2089513216.0000] elapsed time [24.29min]
# load [0] epoch [49/100] iter [300/736] loss [2085337344.0000] elapsed time [24.36min]
# load [0] epoch [49/100] iter [400/736] loss [2050288896.0000] elapsed time [24.42min]
# load [0] epoch [49/100] iter [500/736] loss [2422920448.0000] elapsed time [24.49min]
# load [0] epoch [49/100] iter [600/736] loss [2119856640.0000] elapsed time [24.53min]
# load [0] epoch [49/100] iter [700/736] loss [2016061440.0000] elapsed time [24.58min]
# load [0] epoch [49/100] train loss [2394075650.0870] validation loss [5393994240.0000] elapsed time [24.59 min]
#
# load [0] epoch [50/100] iter [000/736] loss [2041627648.0000] elapsed time [24.60min]
# load [0] epoch [50/100] iter [100/736] loss [2088820992.0000] elapsed time [24.66min]
# load [0] epoch [50/100] iter [200/736] loss [2544580096.0000] elapsed time [24.72min]
# load [0] epoch [50/100] iter [300/736] loss [2395727104.0000] elapsed time [24.77min]
# load [0] epoch [50/100] iter [400/736] loss [1668532992.0000] elapsed time [24.81min]
# load [0] epoch [50/100] iter [500/736] loss [2401454592.0000] elapsed time [24.85min]
# load [0] epoch [50/100] iter [600/736] loss [1956877312.0000] elapsed time [24.89min]
# load [0] epoch [50/100] iter [700/736] loss [1880968448.0000] elapsed time [24.93min]
# load [0] epoch [50/100] train loss [2370257917.9130] validation loss [5221312512.0000] elapsed time [24.95 min]
#
# load [0] epoch [51/100] iter [000/736] loss [2361237504.0000] elapsed time [24.95min]
# load [0] epoch [51/100] iter [100/736] loss [2243155456.0000] elapsed time [25.02min]
# load [0] epoch [51/100] iter [200/736] loss [2799604736.0000] elapsed time [25.09min]
# load [0] epoch [51/100] iter [300/736] loss [2105401344.0000] elapsed time [25.16min]
# load [0] epoch [51/100] iter [400/736] loss [1897086080.0000] elapsed time [25.22min]
# load [0] epoch [51/100] iter [500/736] loss [1987443072.0000] elapsed time [25.29min]
# load [0] epoch [51/100] iter [600/736] loss [2035938560.0000] elapsed time [25.36min]
# load [0] epoch [51/100] iter [700/736] loss [2634908672.0000] elapsed time [25.43min]
# load [0] epoch [51/100] train loss [2367755079.3043] validation loss [5055944704.0000] elapsed time [25.45 min]
#
# load [0] epoch [52/100] iter [000/736] loss [2106782464.0000] elapsed time [25.46min]
# load [0] epoch [52/100] iter [100/736] loss [2267975936.0000] elapsed time [25.53min]
# load [0] epoch [52/100] iter [200/736] loss [3035202048.0000] elapsed time [25.59min]
# load [0] epoch [52/100] iter [300/736] loss [2795432960.0000] elapsed time [25.66min]
# load [0] epoch [52/100] iter [400/736] loss [2590168320.0000] elapsed time [25.73min]
# load [0] epoch [52/100] iter [500/736] loss [2664480768.0000] elapsed time [25.80min]
# load [0] epoch [52/100] iter [600/736] loss [2356382464.0000] elapsed time [25.87min]
# load [0] epoch [52/100] iter [700/736] loss [1912312448.0000] elapsed time [25.94min]
# load [0] epoch [52/100] train loss [2346673844.0000] validation loss [6847513088.0000] elapsed time [25.96 min]
#
# load [0] epoch [53/100] iter [000/736] loss [1998417152.0000] elapsed time [25.97min]
# load [0] epoch [53/100] iter [100/736] loss [1996769024.0000] elapsed time [26.02min]
# load [0] epoch [53/100] iter [200/736] loss [2753634816.0000] elapsed time [26.06min]
# load [0] epoch [53/100] iter [300/736] loss [1901204992.0000] elapsed time [26.10min]
# load [0] epoch [53/100] iter [400/736] loss [2179990016.0000] elapsed time [26.14min]
# load [0] epoch [53/100] iter [500/736] loss [2675407872.0000] elapsed time [26.19min]
# load [0] epoch [53/100] iter [600/736] loss [2483968000.0000] elapsed time [26.25min]
# load [0] epoch [53/100] iter [700/736] loss [2652208640.0000] elapsed time [26.32min]
# load [0] epoch [53/100] train loss [2334066391.4783] validation loss [4245639680.0000] elapsed time [26.35 min]
#
# load [0] epoch [54/100] iter [000/736] loss [2543207936.0000] elapsed time [26.35min]
# load [0] epoch [54/100] iter [100/736] loss [1799203328.0000] elapsed time [26.42min]
# load [0] epoch [54/100] iter [200/736] loss [2087372288.0000] elapsed time [26.49min]
# load [0] epoch [54/100] iter [300/736] loss [1817595904.0000] elapsed time [26.57min]
# load [0] epoch [54/100] iter [400/736] loss [2277083136.0000] elapsed time [26.64min]
# load [0] epoch [54/100] iter [500/736] loss [2618912768.0000] elapsed time [26.71min]
# load [0] epoch [54/100] iter [600/736] loss [1887233152.0000] elapsed time [26.77min]
# load [0] epoch [54/100] iter [700/736] loss [2548810752.0000] elapsed time [26.84min]
# load [0] epoch [54/100] train loss [2327628893.5652] validation loss [5372983296.0000] elapsed time [26.87 min]
#
# load [0] epoch [55/100] iter [000/736] loss [2196271104.0000] elapsed time [26.87min]
# load [0] epoch [55/100] iter [100/736] loss [1971503360.0000] elapsed time [26.94min]
# load [0] epoch [55/100] iter [200/736] loss [2033720064.0000] elapsed time [27.00min]
# load [0] epoch [55/100] iter [300/736] loss [2298528000.0000] elapsed time [27.07min]
# load [0] epoch [55/100] iter [400/736] loss [2694610688.0000] elapsed time [27.14min]
# load [0] epoch [55/100] iter [500/736] loss [1824950272.0000] elapsed time [27.20min]
# load [0] epoch [55/100] iter [600/736] loss [3027472896.0000] elapsed time [27.27min]
# load [0] epoch [55/100] iter [700/736] loss [1939383296.0000] elapsed time [27.34min]
# load [0] epoch [55/100] train loss [2319899090.7826] validation loss [5301547008.0000] elapsed time [27.36 min]
#
# load [0] epoch [56/100] iter [000/736] loss [1991202304.0000] elapsed time [27.37min]
# load [0] epoch [56/100] iter [100/736] loss [2454007040.0000] elapsed time [27.43min]
# load [0] epoch [56/100] iter [200/736] loss [1966381568.0000] elapsed time [27.50min]
# load [0] epoch [56/100] iter [300/736] loss [2688653824.0000] elapsed time [27.57min]
# load [0] epoch [56/100] iter [400/736] loss [1780280320.0000] elapsed time [27.63min]
# load [0] epoch [56/100] iter [500/736] loss [2434837504.0000] elapsed time [27.69min]
# load [0] epoch [56/100] iter [600/736] loss [2691263488.0000] elapsed time [27.75min]
# load [0] epoch [56/100] iter [700/736] loss [1878680832.0000] elapsed time [27.81min]
# load [0] epoch [56/100] train loss [2315609438.6087] validation loss [5144775680.0000] elapsed time [27.83 min]
#
# load [0] epoch [57/100] iter [000/736] loss [3615438336.0000] elapsed time [27.83min]
# load [0] epoch [57/100] iter [100/736] loss [2827279872.0000] elapsed time [27.90min]
# load [0] epoch [57/100] iter [200/736] loss [2468963840.0000] elapsed time [27.97min]
# load [0] epoch [57/100] iter [300/736] loss [1881248512.0000] elapsed time [28.03min]
# load [0] epoch [57/100] iter [400/736] loss [2716936192.0000] elapsed time [28.11min]
# load [0] epoch [57/100] iter [500/736] loss [2753540096.0000] elapsed time [28.18min]
# load [0] epoch [57/100] iter [600/736] loss [2283553280.0000] elapsed time [28.25min]
# load [0] epoch [57/100] iter [700/736] loss [1952219136.0000] elapsed time [28.32min]
# load [0] epoch [57/100] train loss [2300151317.5652] validation loss [5158533632.0000] elapsed time [28.35 min]
#
# load [0] epoch [58/100] iter [000/736] loss [2352508416.0000] elapsed time [28.36min]
# load [0] epoch [58/100] iter [100/736] loss [1871401472.0000] elapsed time [28.43min]
# load [0] epoch [58/100] iter [200/736] loss [2091780096.0000] elapsed time [28.51min]
# load [0] epoch [58/100] iter [300/736] loss [1958436992.0000] elapsed time [28.58min]
# load [0] epoch [58/100] iter [400/736] loss [2794837760.0000] elapsed time [28.66min]
# load [0] epoch [58/100] iter [500/736] loss [2408730880.0000] elapsed time [28.73min]
# load [0] epoch [58/100] iter [600/736] loss [3445108736.0000] elapsed time [28.81min]
# load [0] epoch [58/100] iter [700/736] loss [2197042176.0000] elapsed time [28.87min]
# load [0] epoch [58/100] train loss [2291461716.5217] validation loss [4628439552.0000] elapsed time [28.90 min]
#
# load [0] epoch [59/100] iter [000/736] loss [1833991680.0000] elapsed time [28.90min]
# load [0] epoch [59/100] iter [100/736] loss [1977561216.0000] elapsed time [28.97min]
# load [0] epoch [59/100] iter [200/736] loss [2594612736.0000] elapsed time [29.04min]
# load [0] epoch [59/100] iter [300/736] loss [2162455808.0000] elapsed time [29.11min]
# load [0] epoch [59/100] iter [400/736] loss [2293496832.0000] elapsed time [29.18min]
# load [0] epoch [59/100] iter [500/736] loss [2713131008.0000] elapsed time [29.24min]
# load [0] epoch [59/100] iter [600/736] loss [2574453760.0000] elapsed time [29.31min]
# load [0] epoch [59/100] iter [700/736] loss [2277598720.0000] elapsed time [29.38min]
# load [0] epoch [59/100] train loss [2282500209.2174] validation loss [4863989248.0000] elapsed time [29.40 min]
#
# load [0] epoch [60/100] iter [000/736] loss [2478065664.0000] elapsed time [29.41min]
# load [0] epoch [60/100] iter [100/736] loss [2388493312.0000] elapsed time [29.47min]
# ...
#
# load [2] epoch [90/100] iter [000/736] loss [5189920.0000] elapsed time [142.80min]
# load [2] epoch [90/100] iter [100/736] loss [5853809.0000] elapsed time [142.87min]
# load [2] epoch [90/100] iter [200/736] loss [6322010.0000] elapsed time [142.93min]
# load [2] epoch [90/100] iter [300/736] loss [8381722.0000] elapsed time [143.00min]
# load [2] epoch [90/100] iter [400/736] loss [5049572.5000] elapsed time [143.06min]
# load [2] epoch [90/100] iter [500/736] loss [3262256.7500] elapsed time [143.13min]
# load [2] epoch [90/100] iter [600/736] loss [3666449.0000] elapsed time [143.19min]
# load [2] epoch [90/100] iter [700/736] loss [3749837.0000] elapsed time [143.26min]
# load [2] epoch [90/100] train loss [4955494.3899] validation loss [33633924.0000] elapsed time [143.29 min]
#
# load [2] epoch [91/100] iter [000/736] loss [4180108.5000] elapsed time [143.29min]
# load [2] epoch [91/100] iter [100/736] loss [9044850.0000] elapsed time [143.35min]
# load [2] epoch [91/100] iter [200/736] loss [2763020.2500] elapsed time [143.42min]
# load [2] epoch [91/100] iter [300/736] loss [3047608.7500] elapsed time [143.48min]
# load [2] epoch [91/100] iter [400/736] loss [8417416.0000] elapsed time [143.55min]
# load [2] epoch [91/100] iter [500/736] loss [3816334.5000] elapsed time [143.62min]
# load [2] epoch [91/100] iter [600/736] loss [7994058.0000] elapsed time [143.68min]
# load [2] epoch [91/100] iter [700/736] loss [5819423.5000] elapsed time [143.74min]
# load [2] epoch [91/100] train loss [4910545.0377] validation loss [31529780.0000] elapsed time [143.77 min]
#
# load [2] epoch [92/100] iter [000/736] loss [5073261.0000] elapsed time [143.77min]
# load [2] epoch [92/100] iter [100/736] loss [5217099.0000] elapsed time [143.84min]
# load [2] epoch [92/100] iter [200/736] loss [3803353.5000] elapsed time [143.91min]
# load [2] epoch [92/100] iter [300/736] loss [7434087.0000] elapsed time [143.97min]
# load [2] epoch [92/100] iter [400/736] loss [3402443.7500] elapsed time [144.04min]
# load [2] epoch [92/100] iter [500/736] loss [4776892.5000] elapsed time [144.11min]
# load [2] epoch [92/100] iter [600/736] loss [3829943.2500] elapsed time [144.17min]
# load [2] epoch [92/100] iter [700/736] loss [6333647.0000] elapsed time [144.24min]
# load [2] epoch [92/100] train loss [4842498.4620] validation loss [37417288.0000] elapsed time [144.27 min]
#
# load [2] epoch [93/100] iter [000/736] loss [3533347.5000] elapsed time [144.27min]
# load [2] epoch [93/100] iter [100/736] loss [7769274.0000] elapsed time [144.34min]
# load [2] epoch [93/100] iter [200/736] loss [2968423.0000] elapsed time [144.40min]
# load [2] epoch [93/100] iter [300/736] loss [6122055.0000] elapsed time [144.47min]
# load [2] epoch [93/100] iter [400/736] loss [2730303.5000] elapsed time [144.53min]
# load [2] epoch [93/100] iter [500/736] loss [6010980.5000] elapsed time [144.60min]
# load [2] epoch [93/100] iter [600/736] loss [5306628.5000] elapsed time [144.67min]
# load [2] epoch [93/100] iter [700/736] loss [3925211.2500] elapsed time [144.74min]
# load [2] epoch [93/100] train loss [4878249.7918] validation loss [33574112.0000] elapsed time [144.77 min]
#
# load [2] epoch [94/100] iter [000/736] loss [5831438.0000] elapsed time [144.77min]
# load [2] epoch [94/100] iter [100/736] loss [4452427.5000] elapsed time [144.84min]
# load [2] epoch [94/100] iter [200/736] loss [3821373.5000] elapsed time [144.91min]
# load [2] epoch [94/100] iter [300/736] loss [5829045.5000] elapsed time [144.97min]
# load [2] epoch [94/100] iter [400/736] loss [6104657.5000] elapsed time [145.04min]
# load [2] epoch [94/100] iter [500/736] loss [3656337.0000] elapsed time [145.11min]
# load [2] epoch [94/100] iter [600/736] loss [4455061.0000] elapsed time [145.18min]
# load [2] epoch [94/100] iter [700/736] loss [5085104.0000] elapsed time [145.24min]
# load [2] epoch [94/100] train loss [4858747.7011] validation loss [39817620.0000] elapsed time [145.27 min]
#
# load [2] epoch [95/100] iter [000/736] loss [7796515.5000] elapsed time [145.28min]
# load [2] epoch [95/100] iter [100/736] loss [3017413.5000] elapsed time [145.35min]
# load [2] epoch [95/100] iter [200/736] loss [4315829.5000] elapsed time [145.41min]
# load [2] epoch [95/100] iter [300/736] loss [3992976.0000] elapsed time [145.48min]
# load [2] epoch [95/100] iter [400/736] loss [4660427.0000] elapsed time [145.55min]
# load [2] epoch [95/100] iter [500/736] loss [6293136.5000] elapsed time [145.62min]
# load [2] epoch [95/100] iter [600/736] loss [5824191.0000] elapsed time [145.68min]
# load [2] epoch [95/100] iter [700/736] loss [8477873.0000] elapsed time [145.75min]
# load [2] epoch [95/100] train loss [4990590.7296] validation loss [30127924.0000] elapsed time [145.78 min]
#
# load [2] epoch [96/100] iter [000/736] loss [4056673.2500] elapsed time [145.78min]
# load [2] epoch [96/100] iter [100/736] loss [2946411.0000] elapsed time [145.85min]
# load [2] epoch [96/100] iter [200/736] loss [5814279.0000] elapsed time [145.91min]
# load [2] epoch [96/100] iter [300/736] loss [2811731.7500] elapsed time [145.98min]
# load [2] epoch [96/100] iter [400/736] loss [8499104.0000] elapsed time [146.05min]
# load [2] epoch [96/100] iter [500/736] loss [5514168.5000] elapsed time [146.12min]
# load [2] epoch [96/100] iter [600/736] loss [5286189.5000] elapsed time [146.18min]
# load [2] epoch [96/100] iter [700/736] loss [5893894.0000] elapsed time [146.25min]
# load [2] epoch [96/100] train loss [4884540.8322] validation loss [26527864.0000] elapsed time [146.28 min]
#
# load [2] epoch [97/100] iter [000/736] loss [2959695.0000] elapsed time [146.28min]
# load [2] epoch [97/100] iter [100/736] loss [4693529.0000] elapsed time [146.35min]
# load [2] epoch [97/100] iter [200/736] loss [4921605.5000] elapsed time [146.41min]
# load [2] epoch [97/100] iter [300/736] loss [4890106.0000] elapsed time [146.48min]
# load [2] epoch [97/100] iter [400/736] loss [3589899.0000] elapsed time [146.55min]
# load [2] epoch [97/100] iter [500/736] loss [7969341.0000] elapsed time [146.62min]
# load [2] epoch [97/100] iter [600/736] loss [3340223.5000] elapsed time [146.69min]
# load [2] epoch [97/100] iter [700/736] loss [5594148.0000] elapsed time [146.75min]
# load [2] epoch [97/100] train loss [4857462.7792] validation loss [33271482.0000] elapsed time [146.78 min]
#
# load [2] epoch [98/100] iter [000/736] loss [6571343.0000] elapsed time [146.78min]
# load [2] epoch [98/100] iter [100/736] loss [4325979.5000] elapsed time [146.85min]
# load [2] epoch [98/100] iter [200/736] loss [3593659.7500] elapsed time [146.92min]
# load [2] epoch [98/100] iter [300/736] loss [5150507.0000] elapsed time [146.99min]
# load [2] epoch [98/100] iter [400/736] loss [4389008.0000] elapsed time [147.05min]
# load [2] epoch [98/100] iter [500/736] loss [3675466.0000] elapsed time [147.12min]
# load [2] epoch [98/100] iter [600/736] loss [4941671.0000] elapsed time [147.19min]
# load [2] epoch [98/100] iter [700/736] loss [4498900.0000] elapsed time [147.25min]
# load [2] epoch [98/100] train loss [4988301.1124] validation loss [39152080.0000] elapsed time [147.28 min]
#
# load [2] epoch [99/100] iter [000/736] loss [7475347.0000] elapsed time [147.28min]
# load [2] epoch [99/100] iter [100/736] loss [3561630.0000] elapsed time [147.35min]
# load [2] epoch [99/100] iter [200/736] loss [10978627.0000] elapsed time [147.42min]
# load [2] epoch [99/100] iter [300/736] loss [3456736.5000] elapsed time [147.49min]
# load [2] epoch [99/100] iter [400/736] loss [4881118.0000] elapsed time [147.56min]
# load [2] epoch [99/100] iter [500/736] loss [3046992.5000] elapsed time [147.62min]
# load [2] epoch [99/100] iter [600/736] loss [4570729.5000] elapsed time [147.69min]
# load [2] epoch [99/100] iter [700/736] loss [4299130.5000] elapsed time [147.75min]
# load [2] epoch [99/100] train loss [5025296.7103] validation loss [34405044.0000] elapsed time [147.78 min]
#
# load [3] epoch [0/100] iter [000/736] loss [921190976.0000] elapsed time [147.78min]
# load [3] epoch [0/100] iter [100/736] loss [269438880.0000] elapsed time [147.85min]
# load [3] epoch [0/100] iter [200/736] loss [33297364.0000] elapsed time [147.91min]
# load [3] epoch [0/100] iter [300/736] loss [75912072.0000] elapsed time [147.98min]
# load [3] epoch [0/100] iter [400/736] loss [46404080.0000] elapsed time [148.05min]
# load [3] epoch [0/100] iter [500/736] loss [55959972.0000] elapsed time [148.11min]
# load [3] epoch [0/100] iter [600/736] loss [55936904.0000] elapsed time [148.18min]
# load [3] epoch [0/100] iter [700/736] loss [85883344.0000] elapsed time [148.24min]
# load [3] epoch [0/100] train loss [112114361.2853] validation loss [51564016.0000] elapsed time [148.27 min]
#
# load [3] epoch [1/100] iter [000/736] loss [46680164.0000] elapsed time [148.27min]
# load [3] epoch [1/100] iter [100/736] loss [67658312.0000] elapsed time [148.34min]
# load [3] epoch [1/100] iter [200/736] loss [29599684.0000] elapsed time [148.40min]
# load [3] epoch [1/100] iter [300/736] loss [107480000.0000] elapsed time [148.47min]
# load [3] epoch [1/100] iter [400/736] loss [65397352.0000] elapsed time [148.53min]
# load [3] epoch [1/100] iter [500/736] loss [24546008.0000] elapsed time [148.60min]
# load [3] epoch [1/100] iter [600/736] loss [113275328.0000] elapsed time [148.66min]
# load [3] epoch [1/100] iter [700/736] loss [177956560.0000] elapsed time [148.73min]
# load [3] epoch [1/100] train loss [84735412.1576] validation loss [51296208.0000] elapsed time [148.75 min]
#
# load [3] epoch [2/100] iter [000/736] loss [123097744.0000] elapsed time [148.76min]
# load [3] epoch [2/100] iter [100/736] loss [86417232.0000] elapsed time [148.82min]
# load [3] epoch [2/100] iter [200/736] loss [41452616.0000] elapsed time [148.89min]
# load [3] epoch [2/100] iter [300/736] loss [93529168.0000] elapsed time [148.95min]
# load [3] epoch [2/100] iter [400/736] loss [248704352.0000] elapsed time [149.02min]
# load [3] epoch [2/100] iter [500/736] loss [35542660.0000] elapsed time [149.09min]
# load [3] epoch [2/100] iter [600/736] loss [112294024.0000] elapsed time [149.15min]
# load [3] epoch [2/100] iter [700/736] loss [95492736.0000] elapsed time [149.21min]
# load [3] epoch [2/100] train loss [81458581.5217] validation loss [49548512.0000] elapsed time [149.24 min]
#
# load [3] epoch [3/100] iter [000/736] loss [152309344.0000] elapsed time [149.24min]
# load [3] epoch [3/100] iter [100/736] loss [27556656.0000] elapsed time [149.31min]
# load [3] epoch [3/100] iter [200/736] loss [26609912.0000] elapsed time [149.37min]
# load [3] epoch [3/100] iter [300/736] loss [177534576.0000] elapsed time [149.44min]
# load [3] epoch [3/100] iter [400/736] loss [128183336.0000] elapsed time [149.50min]
# load [3] epoch [3/100] iter [500/736] loss [33497036.0000] elapsed time [149.57min]
# load [3] epoch [3/100] iter [600/736] loss [41789948.0000] elapsed time [149.63min]
# load [3] epoch [3/100] iter [700/736] loss [86208208.0000] elapsed time [149.70min]
# load [3] epoch [3/100] train loss [78604170.2364] validation loss [48697320.0000] elapsed time [149.72 min]
#
# load [3] epoch [4/100] iter [000/736] loss [48476764.0000] elapsed time [149.73min]
# load [3] epoch [4/100] iter [100/736] loss [67860304.0000] elapsed time [149.79min]
# load [3] epoch [4/100] iter [200/736] loss [152549280.0000] elapsed time [149.86min]
# load [3] epoch [4/100] iter [300/736] loss [24794412.0000] elapsed time [149.92min]
# load [3] epoch [4/100] iter [400/736] loss [114110224.0000] elapsed time [149.99min]
# load [3] epoch [4/100] iter [500/736] loss [126667360.0000] elapsed time [150.05min]
# load [3] epoch [4/100] iter [600/736] loss [62421524.0000] elapsed time [150.12min]
# load [3] epoch [4/100] iter [700/736] loss [44754456.0000] elapsed time [150.18min]
# load [3] epoch [4/100] train loss [75491297.1549] validation loss [44997412.0000] elapsed time [150.21 min]
#
# load [3] epoch [5/100] iter [000/736] loss [103834408.0000] elapsed time [150.21min]
# load [3] epoch [5/100] iter [100/736] loss [54675552.0000] elapsed time [150.28min]
# load [3] epoch [5/100] iter [200/736] loss [62887560.0000] elapsed time [150.34min]
# load [3] epoch [5/100] iter [300/736] loss [138825296.0000] elapsed time [150.41min]
# load [3] epoch [5/100] iter [400/736] loss [52636188.0000] elapsed time [150.47min]
# load [3] epoch [5/100] iter [500/736] loss [109827272.0000] elapsed time [150.54min]
# load [3] epoch [5/100] iter [600/736] loss [58196488.0000] elapsed time [150.61min]
# load [3] epoch [5/100] iter [700/736] loss [159187072.0000] elapsed time [150.67min]
# load [3] epoch [5/100] train loss [72450161.3315] validation loss [68491544.0000] elapsed time [150.70 min]
#
# load [3] epoch [6/100] iter [000/736] loss [67037260.0000] elapsed time [150.70min]
# load [3] epoch [6/100] iter [100/736] loss [40763168.0000] elapsed time [150.77min]
# load [3] epoch [6/100] iter [200/736] loss [98491632.0000] elapsed time [150.84min]
# load [3] epoch [6/100] iter [300/736] loss [36962160.0000] elapsed time [150.91min]
# load [3] epoch [6/100] iter [400/736] loss [46423512.0000] elapsed time [150.97min]
# load [3] epoch [6/100] iter [500/736] loss [82855600.0000] elapsed time [151.04min]
# load [3] epoch [6/100] iter [600/736] loss [65758224.0000] elapsed time [151.11min]
# load [3] epoch [6/100] iter [700/736] loss [91887064.0000] elapsed time [151.17min]
# load [3] epoch [6/100] train loss [69603440.6440] validation loss [49571600.0000] elapsed time [151.20 min]
#
# load [3] epoch [7/100] iter [000/736] loss [81120840.0000] elapsed time [151.20min]
# load [3] epoch [7/100] iter [100/736] loss [106513008.0000] elapsed time [151.27min]
# load [3] epoch [7/100] iter [200/736] loss [77631440.0000] elapsed time [151.33min]
# load [3] epoch [7/100] iter [300/736] loss [80976176.0000] elapsed time [151.40min]
# load [3] epoch [7/100] iter [400/736] loss [102177336.0000] elapsed time [151.46min]
# load [3] epoch [7/100] iter [500/736] loss [130652760.0000] elapsed time [151.53min]
# load [3] epoch [7/100] iter [600/736] loss [43357568.0000] elapsed time [151.60min]
# load [3] epoch [7/100] iter [700/736] loss [110505920.0000] elapsed time [151.66min]
# load [3] epoch [7/100] train loss [67094710.3587] validation loss [40168440.0000] elapsed time [151.69 min]
#
# load [3] epoch [8/100] iter [000/736] loss [58688524.0000] elapsed time [151.69min]
# load [3] epoch [8/100] iter [100/736] loss [71178160.0000] elapsed time [151.75min]
# load [3] epoch [8/100] iter [200/736] loss [42570792.0000] elapsed time [151.82min]
# load [3] epoch [8/100] iter [300/736] loss [50756808.0000] elapsed time [151.89min]
# load [3] epoch [8/100] iter [400/736] loss [24665870.0000] elapsed time [151.95min]
# load [3] epoch [8/100] iter [500/736] loss [86938464.0000] elapsed time [152.01min]
# load [3] epoch [8/100] iter [600/736] loss [36531920.0000] elapsed time [152.08min]
# load [3] epoch [8/100] iter [700/736] loss [118159600.0000] elapsed time [152.14min]
# load [3] epoch [8/100] train loss [64381196.8207] validation loss [54904956.0000] elapsed time [152.17 min]
#
# load [3] epoch [9/100] iter [000/736] loss [64713760.0000] elapsed time [152.17min]
# load [3] epoch [9/100] iter [100/736] loss [61750024.0000] elapsed time [152.24min]
# load [3] epoch [9/100] iter [200/736] loss [35835544.0000] elapsed time [152.30min]
# load [3] epoch [9/100] iter [300/736] loss [30297012.0000] elapsed time [152.37min]
# load [3] epoch [9/100] iter [400/736] loss [32893656.0000] elapsed time [152.43min]
# load [3] epoch [9/100] iter [500/736] loss [157577200.0000] elapsed time [152.50min]
# load [3] epoch [9/100] iter [600/736] loss [45634296.0000] elapsed time [152.56min]
# load [3] epoch [9/100] iter [700/736] loss [75482760.0000] elapsed time [152.63min]
# load [3] epoch [9/100] train loss [61531584.1413] validation loss [63417680.0000] elapsed time [152.65 min]
#
# load [3] epoch [10/100] iter [000/736] loss [40891160.0000] elapsed time [152.66min]
# load [3] epoch [10/100] iter [100/736] loss [39644452.0000] elapsed time [152.72min]
# load [3] epoch [10/100] iter [200/736] loss [82363744.0000] elapsed time [152.79min]
# load [3] epoch [10/100] iter [300/736] loss [18079690.0000] elapsed time [152.85min]

# %% [markdown]
# ### Predict

# %%
predictions = []

with torch.no_grad():
    for i in range(35)
        for i, (inputs, labels) in enumerate(test_dataloader[i]):
            inputs = inputs.cuda()

            backcast, forecast = model(inputs.unsqueeze(2))
            predictions.append(forecast.sum(0).data.cuda())
    predictions.append(torch.cat(predictions, dim=0))


# print(predictions)
test_real = test_df.iloc[backcast_length:]  # 입력으로만 사용된 데이터는 제외하였습니다.
# plot_prediction_after_N_days(test_real, train_dataset.scaler.unscale(predictions), N=3)
# Out:
# tensor([[[ 3.8449e+03],
#          [ 1.8153e+03],
#          [ 2.6620e+02],
#          [ 1.2646e+02],
#          [ 2.7547e+03],
#          [ 7.2857e+03],
#          [ 1.2797e+04],
#          [ 1.7702e+04],
#          [ 2.1345e+04],
#          [ 2.3264e+04],
#          [ 2.3922e+04],
#          [ 2.3804e+04],
#          [ 2.3654e+04],
#          [ 2.3989e+04],
#          [ 2.5582e+04],
#          [ 2.7566e+04],
#          [ 2.9025e+04],
#          [ 2.8338e+04],
#          [ 2.5379e+04],
#          [ 2.0611e+04],
#          [ 1.5562e+04],
#          [ 1.1065e+04],
#          [ 8.1041e+03],
#          [ 6.2741e+03],
#          [ 4.5178e+03],
#          [ 2.6919e+03],
#          [ 1.1319e+03],
#          [ 1.2473e+03],
#          [ 3.5734e+03],
#          [ 8.2967e+03],
#          [ 1.3649e+04],
#          [ 1.8481e+04],
#          [ 2.1783e+04],
#          [ 2.3711e+04],
#          [ 2.4111e+04],
#          [ 2.3862e+04],
#          [ 2.3540e+04],
#          [ 2.3953e+04],
#          [ 2.5450e+04],
#          [ 2.7663e+04],
#          [ 2.9207e+04],
#          [ 2.8822e+04],
#          [ 2.5972e+04],
#          [ 2.1377e+04],
#          [ 1.6137e+04],
#          [ 1.1484e+04],
#          [ 8.3606e+03],
#          [ 6.2607e+03],
#          [ 4.5763e+03],
#          [ 2.6567e+03],
#          [ 1.0882e+03],
#          [ 9.2697e+02],
#          [ 3.4329e+03],
#          [ 7.9568e+03],
#          [ 1.3188e+04],
#          [ 1.7990e+04],
#          [ 2.1380e+04],
#          [ 2.3005e+04],
#          [ 2.3584e+04],
#          [ 2.3170e+04],
#          [ 2.2921e+04],
#          [ 2.3302e+04],
#          [ 2.4864e+04],
#          [ 2.6956e+04],
#          [ 2.8363e+04],
#          [ 2.7902e+04],
#          [ 2.5054e+04],
#          [ 2.0455e+04],
#          [ 1.5215e+04],
#          [ 1.0748e+04],
#          [ 7.6775e+03],
#          [ 5.5789e+03],
#          [ 3.8767e+03],
#          [ 1.7904e+03],
#          [ 1.9184e+02],
#          [ 1.1445e+00],
#          [ 2.2180e+03],
#          [ 6.6285e+03],
#          [ 1.1818e+04],
#          [ 1.6513e+04],
#          [ 2.0103e+04],
#          [ 2.1790e+04],
#          [ 2.2328e+04],
#          [ 2.2247e+04],
#          [ 2.2037e+04],
#          [ 2.2533e+04],
#          [ 2.4078e+04],
#          [ 2.6242e+04],
#          [ 2.7742e+04],
#          [ 2.7203e+04],
#          [ 2.4200e+04],
#          [ 1.9460e+04],
#          [ 1.4136e+04],
#          [ 9.6687e+03],
#          [ 6.5051e+03],
#          [ 4.4416e+03],
#          [ 2.6442e+03],
#          [ 7.7079e+02],
#          [-8.4348e+02],
#          [-8.6967e+02],
#          [ 1.6693e+03],
#          [ 6.4378e+03],
#          [ 1.1938e+04],
#          [ 1.7021e+04],
#          [ 2.0905e+04],
#          [ 2.3213e+04],
#          [ 2.4200e+04],
#          [ 2.4389e+04],
#          [ 2.4482e+04],
#          [ 2.5365e+04],
#          [ 2.7112e+04],
#          [ 2.9246e+04],
#          [ 3.0772e+04],
#          [ 3.0200e+04],
#          [ 2.7166e+04],
#          [ 2.2288e+04],
#          [ 1.6625e+04],
#          [ 1.1846e+04],
#          [ 8.4009e+03],
#          [ 6.0817e+03],
#          [ 4.0331e+03],
#          [ 1.9503e+03],
#          [ 2.5065e+02],
#          [ 1.0943e+02],
#          [ 2.5054e+03],
#          [ 7.0434e+03],
#          [ 1.2554e+04],
#          [ 1.7605e+04],
#          [ 2.1401e+04],
#          [ 2.3748e+04],
#          [ 2.4804e+04],
#          [ 2.5001e+04],
#          [ 2.5181e+04],
#          [ 2.5884e+04],
#          [ 2.7523e+04],
#          [ 2.9620e+04],
#          [ 3.0947e+04],
#          [ 3.0066e+04],
#          [ 2.6818e+04],
#          [ 2.1546e+04],
#          [ 1.5819e+04],
#          [ 1.0792e+04],
#          [ 7.0971e+03],
#          [ 4.5644e+03],
#          [ 2.3809e+03],
#          [ 1.8494e+02],
#          [-1.6279e+03],
#          [-1.6565e+03],
#          [ 7.9704e+02],
#          [ 5.2931e+03],
#          [ 1.0761e+04],
#          [ 1.5758e+04],
#          [ 1.9616e+04],
#          [ 2.1662e+04],
#          [ 2.2717e+04],
#          [ 2.2923e+04],
#          [ 2.3038e+04],
#          [ 2.3828e+04],
#          [ 2.5560e+04],
#          [ 2.7747e+04],
#          [ 2.9119e+04],
#          [ 2.8461e+04],
#          [ 2.5526e+04],
#          [ 2.0510e+04],
#          [ 1.5097e+04],
#          [ 1.0485e+04],
#          [ 7.1075e+03],
#          [ 4.7687e+03]]], device='cuda:0')

# %% [markdown]
# ### Submmit
